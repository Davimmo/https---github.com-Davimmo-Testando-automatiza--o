# %%
## Variaveis para o começo
posições=list()
quinas=list()
meios=list()
centros=list()
nucleo=list()

##Listas dos lados que vão receber as posições do cubo
LadoU=[]
LadoL=[]
LadoF=[]
LadoR=[]
LadoB=[]
LadoD=[]

##Definição do cubo
class cubo:

    def start():
        
        for altura in range(1,4):
            for largura in range(1,4):
                for profundidade in range(1,4):
                    posições.append([profundidade,largura,altura])

        for peças in posições:
            if 2 not in peças:
                quinas.append(peças)
            
            elif peças.count(2)==2:
                centros.append(peças)
            
            elif peças==[2,2,2]:
                nucleo.append(peças)
            
            else:
                meios.append(peças)



    def gerar_quinas():print(f'Essas são as coordenadas das quinas:{quinas}')
    def gerar_meios():print(f'Essas são as coordenadas dos meio:{meios}')
    def gerar_centros():print(f'Essas são as coordenadas dos centros:{centros}')
    def gerar_nucleo():print(f'Essa é a coordenada do núcleo:{nucleo}')


##Geração do cubo
cubo.start()

##Procura por posições que preencham os requisitos de cada lado do cubo
def lado(posind,posicub,ladocu):
    

    for i in posições:
        if i[posind]==posicub:
            ladocu.append(i)

##Jogar essas posições nos lados respectivos:
lado(0,3,LadoU)
lado(1,1,LadoL)
lado(2,1,LadoF)
lado(1,3,LadoR)
lado(2,3,LadoB)
lado(0,1,LadoD)



##Criar um dicionario com as informações de cada peça
peças=dict()
dicpeças=[]

for i in posições:
    peças['num']=posições.index(i)+1
    peças['posição']=i


    if i in quinas:
        peças['Tipo de peça']='quina'
    if i in meios:
        peças['Tipo de peça']='meio'
    if i in centros:
        peças['Tipo de peça']='centro'
    if i in nucleo:
        peças['Tipo de peça']='nucleo'


    if i in LadoR: 
        peças ['azul']='PR'
    if i in LadoD: 
        peças['branco']='PD'
    if i in LadoU: 
        peças['amarelo']='PU'
    if i in LadoL: 
        peças['verde']='PL'
    if i in LadoB: 
        peças['vermelho']='PB'
    if i in LadoF: 
        peças['laranja']='PF'


    dicpeças.append(peças)
    peças=dict()



##Procura elementos especificos para as peças e retorna uma lista com cada elemento.

def procurar_no_dicio(a,b):
    ##Procura dentre os valores
    if a=='v':
        elementos_achados=[]
        indices=[]
        for i in dicpeças:
            temp=i.values()
            if b in temp:
                elementos_achados.append(i)
        
        for elemento in elementos_achados:
            indices.append(dicpeças.index(elemento))


        return indices

    ##Procura dentre as chaves
    elif a=='k':
        elementos_achados=[]
        indices=[]
        for i in dicpeças:
            temp=i.keys()
            if b in temp:
                elementos_achados.append(i)

        for elemento in elementos_achados:
            indices.append(dicpeças.index(elemento))


        return indices
        

todos_os_lados=[LadoU,LadoL,LadoF,LadoR,LadoB,LadoD]
todas_as_cores=['amarelo','verde','laranja','azul','vermelho','branco']



ciclo_de_U=[dicpeças[20],dicpeças[23],dicpeças[26],dicpeças[17],dicpeças[8],dicpeças[5],dicpeças[2],dicpeças[11]]
ciclo_de_L=[dicpeças[20],dicpeças[19],dicpeças[18],dicpeças[11],dicpeças[9],dicpeças[2],dicpeças[1],dicpeças[0]]
ciclo_de_F=[dicpeças[2],dicpeças[5],dicpeças[8],dicpeças[7],dicpeças[6],dicpeças[3],dicpeças[0],dicpeças[1]]
ciclo_de_R=[dicpeças[24],dicpeças[25],dicpeças[26],dicpeças[17],dicpeças[8],dicpeças[7],dicpeças[6],dicpeças[15]]
ciclo_de_B=[dicpeças[26],dicpeças[23],dicpeças[20],dicpeças[11],dicpeças[2],dicpeças[5],dicpeças[8],dicpeças[17]]
ciclo_de_D=[dicpeças[0],dicpeças[2],dicpeças[5],dicpeças[7],dicpeças[8],dicpeças[5],dicpeças[2],dicpeças[1]]

listadeciclos=[ciclo_de_U,ciclo_de_L,ciclo_de_F,ciclo_de_R,ciclo_de_B,ciclo_de_D]

for i in ciclo_de_F:
    print(i)
    
ciclo_de_Fnovo = ciclo_de_F[2:] + ciclo_de_F[:2] 

print('-'*100)
for i in ciclo_de_Fnovo:
    
    print(i)

variavel=0
for i in ciclo_de_F:
    i['posição']=ciclo_de_Fnovo[variavel]['posição']
    variavel+=1


print('-'*100)
for i in ciclo_de_F:
    
    print(i)


temp2=0
for i in ciclo_de_F:
    
    lista1=i.values
    lista2=ciclo_de_Fnovo[temp2]
    lista2.values

    

    temp2+=1
# Out:
# {'num': 3, 'posição': [3, 1, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 6, 'posição': [3, 2, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------------------------------------------------
# {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 3, 'posição': [3, 1, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 6, 'posição': [3, 2, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------------------------------------------------
# {'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 9, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 8, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# {'num': 7, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 4, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 1, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 2, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# aqui{'num': 9, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# aqui{'num': 8, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# aqui{'num': 7, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# aqui{'num': 4, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# aqui{'num': 1, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# aqui{'num': 2, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# aqui{'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# aqui{'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}

# %%
for indice,valor in enumerate(dicpeças):
    print(indice,valor)
# Out:
# 0 {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# 1 {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# 2 {'num': 3, 'posição': [3, 1, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# 3 {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# 4 {'num': 5, 'posição': [2, 2, 1], 'Tipo de peça': 'centro', 'laranja': 'PF'}
# 5 {'num': 6, 'posição': [3, 2, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# 6 {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# 7 {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# 8 {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# 9 {'num': 10, 'posição': [1, 1, 2], 'Tipo de peça': 'meio', 'branco': 'PD', 'verde': 'PL'}
# 10 {'num': 11, 'posição': [2, 1, 2], 'Tipo de peça': 'centro', 'verde': 'PL'}
# 11 {'num': 12, 'posição': [3, 1, 2], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'verde': 'PL'}
# 12 {'num': 13, 'posição': [1, 2, 2], 'Tipo de peça': 'centro', 'branco': 'PD'}
# 13 {'num': 14, 'posição': [2, 2, 2], 'Tipo de peça': 'nucleo'}
# 14 {'num': 15, 'posição': [3, 2, 2], 'Tipo de peça': 'centro', 'amarelo': 'PU'}
# 15 {'num': 16, 'posição': [1, 3, 2], 'Tipo de peça': 'meio', 'azul': 'PR', 'branco': 'PD'}
# 16 {'num': 17, 'posição': [2, 3, 2], 'Tipo de peça': 'centro', 'azul': 'PR'}
# 17 {'num': 18, 'posição': [3, 3, 2], 'Tipo de peça': 'meio', 'azul': 'PR', 'amarelo': 'PU'}
# 18 {'num': 19, 'posição': [1, 1, 3], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'vermelho': 'PB'}
# 19 {'num': 20, 'posição': [2, 1, 3], 'Tipo de peça': 'meio', 'verde': 'PL', 'vermelho': 'PB'}
# 20 {'num': 21, 'posição': [3, 1, 3], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'vermelho': 'PB'}
# 21 {'num': 22, 'posição': [1, 2, 3], 'Tipo de peça': 'meio', 'branco': 'PD', 'vermelho': 'PB'}
# 22 {'num': 23, 'posição': [2, 2, 3], 'Tipo de peça': 'centro', 'vermelho': 'PB'}
# 23 {'num': 24, 'posição': [3, 2, 3], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'vermelho': 'PB'}
# 24 {'num': 25, 'posição': [1, 3, 3], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'vermelho': 'PB'}
# 25 {'num': 26, 'posição': [2, 3, 3], 'Tipo de peça': 'meio', 'azul': 'PR', 'vermelho': 'PB'}
# 26 {'num': 27, 'posição': [3, 3, 3], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'vermelho': 'PB'}

# %%
test_list = [1, 4, 6, 7, 2] 
print ("Original list : " + str(test_list)) 
test_list = test_list[3:] + test_list[:3] 
print ("List after left rotate by 3 : " + str(test_list)) 
test_list = test_list[-3:] + test_list[:-3] 
print ("List after right rotate by 3(back to original) : "
                                         + str(test_list))
# Out:
# Original list : [1, 4, 6, 7, 2]
# List after left rotate by 3 : [7, 2, 1, 4, 6]
# List after right rotate by 3(back to original) : [1, 4, 6, 7, 2]

# %%
# dicionario={'fruta':'pera','veiculo':'moto','moeda':'dolar'}
# dicionario.items()

# outrodic={'cor':'azul','nome':'roberto','carreira':'professor'}

# lista_de_itens=.items()

# for k,v in lista_de_itens:
#     print(k)
#     print(v)

testando=['cafe','coca','batata','pepino','churrasco']

testando[2]='pepino'

print(testando)
# Out:
# ['cafe', 'coca', 'pepino', 'pepino', 'churrasco']
