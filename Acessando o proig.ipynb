# %%
import time
import pyautogui as pauto
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome()


time.sleep(0.5)
driver.get("https://www.educacao.petrolina.pe.gov.br/ator/educadores")
driver.set_window_size(976, 1040)
driver.find_element(By.CSS_SELECTOR, "html").click()
driver.find_element(By.CSS_SELECTOR, ".LayoutLoginCampos").click()
driver.find_element(By.ID, "login").click()
driver.find_element(By.ID, "login").send_keys("Davi.BC")
driver.find_element(By.ID, "senha").send_keys("@Vk5644202510")
driver.find_element(By.ID, "senha").send_keys(Keys.ENTER)
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, ".menuAcessoRestrito").click()
time.sleep(0.5)
driver.find_element(By.LINK_TEXT, "Gestão Escolar").click()
time.sleep(0.5)
driver.find_element(By.CSS_SELECTOR, ".icon-eol1331").click()
time.sleep(0.5)
driver.find_element(By.XPATH, "//div[3]/div/div/div/div").click()
time.sleep(0.5)
driver.find_element(By.XPATH, "//ul/li").click()
time.sleep(0.5)
driver.find_element(By.XPATH, "//ul/li[4]").click()
time.sleep(0.5)
driver.switch_to.frame(0)
time.sleep(0.5)

##Aqui começa o loop for para colocar o nome dos alunos

##Aqui vai o nome do aluno

Alunos=['BERNARDO MOURA DA SILVA',
'DANIEL FELIPE PEREIRA DA SILVA',
'DAVI LUCAS LIMA DA CRUZ',
'DEYVID NUNES DOS ANJOS',
'ELISA SEGUNDO',
'ERICK RHUAN PRATI FERREIRA DA SILVA',
'ESTHER CARVALHO DIAS',
'ESTHER OLIVEIRA NOVAIS']

Inep=['205575895767',
'206650442249',
'185350683259',
'205575891931',
'205575896305',
'205575891699',
'205575895252',
'205575896810']

var1=int(0)
time.sleep(0.5)


for Aluno in Alunos:
    driver.find_element(By.NAME, "txtAluno").send_keys(Alunos[var1])
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="lnk_pesquisar"]/img').click()
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[3]/div[4]/div/table/tbody/tr[2]/td[3]/label').click()
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="lnk_alterar"]/img').click()
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="tabCadastroAluno_tablist_cpDocumentos"]').click()
    time.sleep(1)
    
    ##Aqui vai o inepe 
    driver.find_element(By.XPATH,'//*[@id="cpDocumentos"]/table/tbody/tr[17]/td[2]/input').send_keys(Inep[var1])
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr/td/input[1]').click()
    time.sleep(1)
    ##Limpa o input
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr[3]/td[2]/input').clear()
    time.sleep(2)
    var1+=1

# %%
Alunos=['LAZÁRO BERNARDO DO NASCIMENTO DELMAN	']
Inep=['111111111111']
var1=int(0)
time.sleep(1)





for Aluno in Alunos:
    driver.find_element(By.NAME, "txtAluno").send_keys(Alunos[var1])
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="lnk_pesquisar"]/img').click()
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[3]/div[4]/div/table/tbody/tr[2]/td[3]/label').click()
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="lnk_alterar"]/img').click()
    time.sleep(2)
    driver.find_element(By.XPATH,'//*[@id="tabCadastroAluno_tablist_cpDocumentos"]').click()
    time.sleep(2)
    
    ##Aqui vai o inepe 
    driver.find_element(By.XPATH,'//*[@id="cpDocumentos"]/table/tbody/tr[17]/td[2]/input').send_keys(Inep[var1])
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr/td/input[1]').click()
    time.sleep(1)
    ##Limpa o input
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr[3]/td[2]/input').clear()
    
    var1+=1

# %%
driver.find_element(By.LINK_TEXT, "Cancelar").click()
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# c:\Users\davi2\Testando automatização\Acessando o proig.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/davi2/Testando%20automatiza%C3%A7%C3%A3o/Acessando%20o%20proig.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> driver.find_element(By.LINK_TEXT, "Cancelar").click()
#
# File c:\Users\davi2\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File c:\Users\davi2\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
# ...
